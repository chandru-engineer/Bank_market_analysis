# %%
<h1><center>Bank Marketing Analysis</h1>

# %% [markdown]
# <h1><center>Preprocessing</center></h1>

# %%
## import packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## import data 

df = pd.read_csv('bank_marketing_dataset.csv')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# subscribed        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder


## job
job_encoder = LabelEncoder()
df['job'] = job_encoder.fit_transform(df['job'])


## marital
marital_encoder = LabelEncoder()
df['marital'] = marital_encoder.fit_transform(df['marital'])


## education
education_encoder = LabelEncoder()
df['education'] = education_encoder.fit_transform(df['education'])


## default
default_encoder = LabelEncoder()
df['default'] = default_encoder.fit_transform(df['default'])


## housing
housing_encoder = LabelEncoder()
df['housing'] = housing_encoder.fit_transform(df['housing'])


## loan
loan_encoder = LabelEncoder()
df['loan'] = loan_encoder.fit_transform(df['loan'])


## contact
contact_encoder = LabelEncoder()
df['contact'] = contact_encoder.fit_transform(df['contact'])


## month
month_encoder = LabelEncoder()
df['month'] = month_encoder.fit_transform(df['month'])


## day_of_week
day_of_week_encoder = LabelEncoder()
df['day_of_week'] = day_of_week_encoder.fit_transform(df['day_of_week'])


## poutcome
poutcome_encoder = LabelEncoder()
df['poutcome'] = poutcome_encoder.fit_transform(df['poutcome'])


## subscribed
subscribed_encoder = LabelEncoder()
df['subscribed'] = subscribed_encoder.fit_transform(df['subscribed'])

# %%
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         1           1.1
# 1            1  ...         1    999         0         1           1.1
# 2            1  ...         1    999         0         1           1.1
# 3            1  ...         1    999         0         1           1.1
# 4            1  ...         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  int32
#  2   marital         41188 non-null  int32
#  3   education       41188 non-null  int32
#  4   default         41188 non-null  int32
#  5   housing         41188 non-null  int32
#  6   loan            41188 non-null  int32
#  7   contact         41188 non-null  int32
#  8   month           41188 non-null  int32
#  9   day_of_week     41188 non-null  int32
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  int32
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
## Save as CSV File

# df.to_csv('Preprocessed.csv', header=True, index=False)

# %% [markdown]
# <h1><center>PCA</center></h1>

# %%
## import needed packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## load preprocessed dataset

df = pd.read_csv('Preprocessed.csv')
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         1           1.1
# 1            1  ...         1    999         0         1           1.1
# 2            1  ...         1    999         0         1           1.1
# 3            1  ...         1    999         0         1           1.1
# 4            1  ...         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed
# ...

# %%
X = df.drop('subscribed', axis=1)

y = df['subscribed']

# %%
from sklearn.preprocessing import StandardScaler

# Standardizing the features
X = StandardScaler().fit_transform(X)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
PrincipalComponents = pca.fit_transform(X)
pca_df = pd.DataFrame(data = PrincipalComponents, columns = ['pc1', 'pc2'])

# %%
pca_df.head()
# Out:
#         pc1       pc2
# 0 -1.634979  1.208213
# 1 -1.892614  1.314860
# 2 -1.437729  0.709083
# 3 -1.607007  0.813948
# 4 -1.548009  1.152562

# %%
final_df = pd.concat([pca_df, y], axis = 1)

# %%
final_df.head()
# Out:
#         pc1       pc2  subscribed
# 0 -1.634979  1.208213           0
# 1 -1.892614  1.314860           0
# 2 -1.437729  0.709083           0
# 3 -1.607007  0.813948           0
# 4 -1.548009  1.152562           0

# %%
plt.figure(dpi=150)
ax = sns.scatterplot(data=final_df, x="pc1", y="pc2", hue="subscribed")
plt.show()

# %%
## Save as CSV File

# final_df.to_csv('PCA_Bank_marketing.csv', header=True, index=False)

# %% [markdown]
# <h1><center>MODELS</center></h1>

# %%
## import packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
# load data

df = pd.read_csv("PCA_Bank_marketing.csv")
df.head()
# Out:
#         pc1       pc2  subscribed
# 0 -1.634284  1.154582           0
# 1 -1.892086  1.250669           0
# 2 -1.438187  0.660978           0
# 3 -1.606774  0.753521           0
# 4 -1.546778  1.201585           0

# %%
X = df.drop('subscribed', axis=1)
y = df['subscribed']

# %%
from sklearn.model_selection import train_test_split

#help(train_test_split)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# <h1><center>CNN</center></h1>

# %%
model = Sequential([
    Dense(32, activation='relu', input_shape=(2,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, y_train,
          batch_size=32, epochs=100,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 863/863 [==============================] - 3s 2ms/step - loss: 0.3288 - accuracy: 0.8940 - val_loss: 0.2980 - val_accuracy: 0.8971
# Epoch 2/100
# 863/863 [==============================] - 2s 2ms/step - loss: 0.2931 - accuracy: 0.8985 - val_loss: 0.2934 - val_accuracy: 0.8967
# Epoch 3/100
# 863/863 [==============================] - 2s 2ms/step - loss: 0.2902 - accuracy: 0.8984 - val_loss: 0.2912 - val_accuracy: 0.8967
# Epoch 4/100
# 863/863 [==============================] - 2s 2ms/step - loss: 0.2887 - accuracy: 0.8984 - val_loss: 0.2906 - val_accuracy: 0.8963
# Epoch 5/100
# 863/863 [==============================] - 2s 2ms/step - loss: 0.2880 - accuracy: 0.8982 - val_loss: 0.2897 - val_accuracy: 0.8966
# Epoch 6/100
# 863/863 [==============================] - 2s 2ms/step - loss: 0.2875 - accuracy: 0.8981 - val_loss: 0.2888 - val_accuracy: 0.8969
# Epoch 7/100
# ...

# %%
# graph of loss function 

plt.figure(figsize=(6, 3), dpi=150)
plt.plot(hist.history['loss'])

plt.xlabel("epochs")
plt.ylabel("loss")

plt.title("loss vs epochs")
plt.show()

# %%
# graph of loss function 

plt.figure(figsize=(6, 3), dpi=150)

plt.plot(hist.history['accuracy'])
plt.xlabel("epochs")
plt.ylabel("accuracy and accuracy")
plt.legend()
plt.title("accuracy vs epochs")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# <h1><center>RNN</center></h1>

# %%
#import libraries and packages:
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import SimpleRNN
from keras.layers import Dropout

#Initialize RNN:
model_RNN = Sequential()

#Adding the first RNN layer and some Dropout regularization
model_RNN.add(SimpleRNN(units = 50, activation='tanh', return_sequences=True, input_shape= (X_train.shape[1],1)))
model_RNN.add(Dropout(0.2))

#Adding the second RNN layer and some Dropout regularization
model_RNN.add(SimpleRNN(units = 50, activation='tanh', return_sequences=True))
model_RNN.add(Dropout(0.2))

#Adding the third RNN layer and some Dropout regularization
model_RNN.add(SimpleRNN(units = 50, activation='tanh', return_sequences=True))
model_RNN.add(Dropout(0.2))

#Adding the fourth RNN layer and some Dropout regularization
model_RNN.add(SimpleRNN(units = 50))
model_RNN.add(Dropout(0.2))

#Adding the output layer
model_RNN.add(Dense(units = 1))

#Compile the RNN
model_RNN.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

#Fitting the RNN to the Training set
history_RNN = model_RNN.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 863/863 [==============================] - 8s 6ms/step - loss: 0.1438 - accuracy: 0.8616
# Epoch 2/100
# 863/863 [==============================] - 5s 5ms/step - loss: 0.0922 - accuracy: 0.8914
# Epoch 3/100
# 863/863 [==============================] - 5s 5ms/step - loss: 0.0874 - accuracy: 0.8944
# Epoch 4/100
# 863/863 [==============================] - 5s 5ms/step - loss: 0.0863 - accuracy: 0.8940
# Epoch 5/100
# 863/863 [==============================] - 5s 5ms/step - loss: 0.0854 - accuracy: 0.8958
# Epoch 6/100
# 863/863 [==============================] - 5s 5ms/step - loss: 0.0851 - accuracy: 0.8956
# Epoch 7/100
# 863/863 [==============================] - 5s 5ms/step - loss: 0.0850 - accuracy: 0.8959
# Epoch 8/100
# 863/863 [==============================] - 5s 5ms/step - loss: 0.0851 - accuracy: 0.8960
# Epoch 9/100
# 863/863 [==============================] - 5s 5ms/step - loss: 0.0850 - accuracy: 0.8956
# Epoch 10/100
# ...

# %%
# graph of loss function 

plt.figure(figsize=(6, 3), dpi=150)
plt.plot(history_RNN.history['loss'])

plt.xlabel("epochs")
plt.ylabel("loss")
#plt.legend()
plt.title("loss vs epochs")
plt.show()

# %%
# graph of loss function 

plt.figure(figsize=(6, 3), dpi=150)
plt.plot(history_RNN.history['accuracy'])

plt.xlabel("epochs")
plt.ylabel("loss")
#plt.legend()
plt.title("loss vs epochs")
plt.show()

# %% [markdown]
# <h1><center>Kmeans</h1></center>

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
# load data

df = pd.read_csv("PCA_Bank_marketing.csv")
df.head()
# Out:
#         pc1       pc2  subscribed
# 0 -1.634284  1.154582           0
# 1 -1.892086  1.250669           0
# 2 -1.438187  0.660978           0
# 3 -1.606774  0.753521           0
# 4 -1.546778  1.201585           0

# %%
X = df.drop('subscribed', axis=1)

# %%
kmeans = KMeans(2)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
identified_clusters = kmeans.fit_predict(X)
identified_clusters
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
df_with_clusters = df.copy()
df_with_clusters['Clusters'] = identified_clusters 
plt.scatter(df_with_clusters['pc1'],df_with_clusters['pc2'],c=df_with_clusters['Clusters'],cmap='rainbow')

# %% [markdown]
# WCSS is the sum of squared distance between each point and the centroid in a cluster. When we plot the WCSS with the K value, the plot looks like an Elbow. As the number of clusters increases, the WCSS value will start to decrease. WCSS value is largest when K = 1

# %%
wcss=[]
for i in range(1,7):
    kmeans = KMeans(i)
    kmeans.fit(X)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

number_clusters = range(1,7)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# <h1><center>Hierarchical Clustering</h1></center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## load dataset

df = pd.read_csv('Preprocessed.csv')
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   56    3        1          0        0        0     0        1      6
# 1   57    7        1          3        1        0     0        1      6
# 2   37    7        1          3        0        2     0        1      6
# 3   40    0        1          1        0        0     0        1      6
# 4   56    7        1          3        0        0     2        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         1    999         0         1           1.1
# 1            1  ...         1    999         0         1           1.1
# 2            1  ...         1    999         0         1           1.1
# 3            1  ...         1    999         0         1           1.1
# 4            1  ...         1    999         0         1           1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  subscribed
# ...

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(df, method='ward'))

# %% [markdown]
# <h1><center>DBSCAN</center></h1>

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import matplotlib

# %%
## load dataset

df = pd.read_csv('PCA_Bank_marketing.csv')
df.head()
# Out:
#         pc1       pc2  subscribed
# 0 -1.634284  1.154582           0
# 1 -1.892086  1.250669           0
# 2 -1.438187  0.660978           0
# 3 -1.606774  0.753521           0
# 4 -1.546778  1.201585           0

# %%
from sklearn.cluster import DBSCAN
dbscan=DBSCAN()
df_ = df.drop('subscribed', axis=1)
dbscan.fit(df_)
# Out:
# DBSCAN()

# %%
df_['DBSCAN_labels']=dbscan.labels_ 

df_.head()

# Plotting resulting clusters
plt.figure(figsize=(10,10))
plt.scatter(df_['pc1'],df_['pc2'],c=df_['DBSCAN_labels'],s=15)
plt.title('DBSCAN Clustering',fontsize=20)
plt.xlabel('Feature 1',fontsize=14)
plt.ylabel('Feature 2',fontsize=14)
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import datasets
from sklearn.preprocessing import scale
from pyclustertend import hopkins ## the hopkins test
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
## load dataset

df = pd.read_csv('PCA_Bank_marketing.csv')
df.head()
# Out:
#         pc1       pc2  subscribed
# 0 -1.634284  1.154582           0
# 1 -1.892086  1.250669           0
# 2 -1.438187  0.660978           0
# 3 -1.606774  0.753521           0
# 4 -1.546778  1.201585           0

# %%
X = df.drop('subscribed', axis=1)
y = df['subscribed']

# %%
hopkins(X, X.shape[0])
# Out:
# 0.01122251567568519

# %%
hopkins(scale(X),X.shape[0])
# Out:
# 0.0117281989179665

# %%
pca = PCA(n_components = 2)

X_pca = pca.fit_transform(scale(X))

labels = y

cdict = {0 : "green", 1 : "red"}
labl = {0: "No", 1 : "yes"}
marker = {0 : "o", 1: "*"}
alpha = {0: 0.5, 1: 0.5}

#fig = plt.figure(figsize=(10, 10))
#ax = fig.add_subplot(111, projection='3d')

fig = plt.figure(figsize=(10, 10))


for l in np.unique(labels):
    ix = np.where(labels == l)
    plt.scatter(X_pca[ix,0],X_pca[ix,1], c = cdict[l], s=40, label = labl[l], marker = marker[l], alpha = alpha[l])

#plt.scatter(X_pca[:,0],X_pca[:,1]);
plt.xlabel("first principal component")
plt.xlabel("second principal component")
plt.title("PCA  : Bank Marketing")
# Out:
# Text(0.5, 1.0, 'PCA  : Bank Marketing')
